# %% [markdown]
# # Advanced Certification Program in Computational Data Science
# ## A program by IISc and TalentSprint
# ### Assignment 4: PySpark Transform and Actions

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# At the end of the experiment, you will be able to
#
# * Perform RDD (Resilient Distributed Datasets) operations including:
#
#   1.   Transformations
#   2.   Actions
#
# * Obtain an overview of shuffle operations
# * Implement RDD based model

# %% [markdown]
# ## Information

# %% [markdown]
# **Overview about Spark, PySpark and Apache Spark in simple language**
#
# **Spark:** A data computational framework that handles Big data.
#
# **PySpark:** A tool to support Python with Spark
#
# **Apache Spark:** It is an open-source cluster-computing framework, built around speed, ease of use, and streaming analytics.
#
# * Like Spark, PySpark helps data scientists to work with (RDDs) Resilient Distributed Datasets. It is also used to work on Data frames. PySpark can be used to work with machine learning algorithms as well.
#
# ### ***Spark RDD is a major concept in Apache Spark***
#
# **Resilient Distributed Datasets:**
#
# **Resilient:**    because RDDs are immutable (can’t be modified once created)                        and fault tolerant.
#
# **Distributed:**  because it is distributed across clusters
#
# **Dataset:**      because it holds data.
#
# **Why RDD?**
#
# * Apache Spark lets you treat your input files almost like any other variable, which you cannot do in Hadoop MapReduce.
# * RDDs are automatically distributed across the network by means of Partitions.
#
# RDDs are divided into smaller chunks called Partitions, and when you execute some action, a task is launched per partition. This means, the more the number of partitions, the more will be the parallelism.
#
# Spark automatically decides the number of partitions that an RDD has to be divided into, but you can also specify the number of partitions when creating an RDD. These partitions of an RDD are distributed across all the nodes in the network.
#
# **Difference between Dataframe and RDD (Resilient Distributed Datasets):**
#
# **Dataframe:**
# * Automatically finds out the schema of the dataset.
# * Performs aggregation faster than RDDs, as it provides an easy API to perform aggregation operations.
#
# **RDD:**
# * We need to define the schema manually.
# * RDD is slower than Dataframes to perform simple operations like grouping the data.

# %% [markdown]
# **Creating an RDD**
#
# **There are three ways to create an RDD in Spark:**
# 1. Parallelizing already existing collection in the driver program.
#
#   The key point to note in a parallelized collection is the number of partitions the dataset is divided into. Spark will run one task for each partition of the cluster. We require two to four partitions for each CPU in the cluster. Spark sets the number of partition based on our cluster.
#
# 2. Referencing a dataset in an external storage system (e.g. HDFS, Hbase, shared file system).
#
#   In Spark, the distributed dataset can be formed from any data source supported by Hadoop, including the local file system, HDFS, Cassandra, HBase etc. In this, the data is loaded from the external dataset.
#
#   * csv (String path): It loads a CSV file and returns the result as a Dataset.
#
#   * json (String path): It loads a JSON file (one object per line) and returns the result as a Dataset
#
#   * textFile (String path) It loads text files and returns a Dataset of String.
#
# 3. Creating RDD from already existing RDDs.
#
#   Transformation mutates one RDD into another RDD, this transformation is the way to create an RDD from an already existing RDD. This creates a difference between Apache Spark and Hadoop MapReduce.

# %% [markdown]
# **Actions/Transformations**
#
# There are two types of operations that you can perform on an RDD-
# * Transformations
# * Actions.
#
# **Transformation** applies some function on an RDD and creates a new RDD, it does not modify the RDD that you apply the function on. Also, the new RDD keeps a pointer to its parent RDD.
#
# When you call a transformation, Spark does not execute it immediately, instead it creates a lineage. A lineage keeps track of what all transformations have to be applied on that RDD, including from where it has to read the data.
#
#
# **Action** is used to either save the result to some location or to display it. You can also print the RDD lineage information by using the command:
#
# "filtered.toDebugString" -> (*filtered* is the RDD here).

# %% [markdown]
# ![img](https://cdn.iisc.talentsprint.com/CDS/Images/Pyspark_RDD.JPG)

# %% [markdown]
# ### Setup Steps:

# %% [markdown]
#  **Install PySpark**

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 38 kB/s
# Collecting py4j==0.10.9.2
#   Downloading py4j-0.10.9.2-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 64.4 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805911 sha256=44c5b7c7e83ffc7422a5ff8704d456a52d23464c991e4cf7dd5363d411b9318c
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.2 pyspark-3.2.0

# %% [markdown]
# **Creating Spark Session**
#
# Spark session is a combined entry point of a Spark application, which came into implementation from Spark 2.0 (Instead of having various contexts, everything is encapsulated in a Spark session)

# %%
# Start spark session
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, udf  # User Defined Functions
from pyspark.sql.types import StringType
spark = SparkSession.builder.appName('Rdd').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://a4d9668ac43f:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Rdd</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Accessing sparkContext from sparkSession instance.
sc = spark.sparkContext

# %% [markdown]
# ### Spark Python Transformations

# %% [markdown]
# **map()** - A map transformation is useful when we need to transform an RDD by applying a function to each element.

# %%
# Return a new RDD by applying a function to each element of this RDD.
rdd = sc.parallelize(["b", "a", "c"])
sorted(rdd.map(lambda x: (x, 1)).collect())
# Out:
# [('a', 1), ('b', 1), ('c', 1)]

# %% [markdown]
# **take()** - Take the first num elements of the RDD.
#
# It works by first scanning one partition, and use the results from that partition to estimate the number of additional partitions needed to satisfy the limit

# %%
sc.parallelize([2, 3, 4, 5, 6]).cache().take(2) #take()
# Out:
# [2, 3]

# %%
sc.parallelize(range(100), 100).filter(lambda x: x > 90).take(3) #take()
# Out:
# [91, 92, 93]

# %% [markdown]
# **flatMap()** - The flatMap transformation will return a new RDD by first applying a function to all elements of this RDD, and then flattening the results. This is the main difference between the flatMap and *map transformations.*

# %%
s0 = sc.parallelize([3, 4, 5])
s0.flatMap(lambda x: [x, x*x]).collect()
# Out:
# [3, 9, 4, 16, 5, 25]

# %% [markdown]
# Compare the same function using map()

# %%
sc.parallelize([3,4,5]).map(lambda x: [x,  x*x]).collect()
# Out:
# [[3, 9], [4, 16], [5, 25]]

# %% [markdown]
# **filter()** - The filter transformation returns a new dataset formed by selecting  those elements of the source on which func returns true.

# %%
rdd = sc.parallelize([1, 2, 3, 4, 5])
rdd.filter(lambda x: x % 2 == 0).collect() # Return a new RDD containing only the elements that satisfy a predicate.
# Out:
# [2, 4]

# %% [markdown]
# **groupByKey()** - We can apply the “groupByKey” transformations on (key,val) pair RDD. The “groupByKey” will group the values for each key in the original RDD. It will create a new pair, where the original key corresponds to this collected group of values.

# %%
x = sc.parallelize([("a" , 1), ("b" , 1), ("a" , 1)])
x.groupByKey().map(lambda x : (x[0], list(x[1]))).collect()
# Out:
# [('b', [1]), ('a', [1, 1])]

# %% [markdown]
# **reduceByKey()** - Merge the values for each key using an associative reduce function.

# %%
from operator import add
rdd = sc.parallelize([("a", 1), ("b", 1), ("a", 1)])
sorted(rdd.reduceByKey(add).collect())
# Out:
# [('a', 2), ('b', 1)]

# %% [markdown]
# **mapPartitions()** - Is similar to map, but runs separately on each partition (block) of the RDD

# %%
wordsList = ['cat', 'elephant', 'rat', 'rat', 'cat']

wordsRDD = sc.parallelize(wordsList, 4) # number of partitions - 4

print(wordsRDD.collect())

itemsRDD = wordsRDD.mapPartitions(lambda iterator: [','.join(iterator)])
# mapPartitions() loops through 4 partitions and combines('rat,cat') in 4th iteration.
itemsRDD.collect()
# Out:
# ['cat', 'elephant', 'rat', 'rat', 'cat']
# ['cat', 'elephant', 'rat', 'rat,cat']

# %%
L = range(1,10)

# number of partitions - 3
parallel = sc.parallelize(L , 3)
def f(iterator): 
  yield sum(iterator)

parallel.mapPartitions(f).collect()

# Results [6,15,24] are created because mapPartitions() loops through 3 partitions, 
# Partion 1: 1+2+3 = 6, Partition 2: 4+5+6 = 15, Partition 3: 7+8+9 = 24
# Out:
# [6, 15, 24]

# %%
# number of partitions - 2
rdd = sc.parallelize([1, 2, 3, 4] , 2)
def f(iterator):
  yield sum(iterator)

rdd.mapPartitions(f).collect() 

# Results [3, 7], partition 1 : 1+2 = 3, partition 2 : 3+4 =7
# Out:
# [3, 7]

# %% [markdown]
# **mapPartitionsWithIndex()** - Return a new RDD by applying a function to each partition of this RDD, while tracking the index of the original partition.

# %%
rdd = sc.parallelize([1, 2, 3, 4], 4)
def f(splitIndex, iterator): yield splitIndex
rdd.mapPartitionsWithIndex(f).sum()
# Out:
# 6

# %% [markdown]
# ### Spark Python Actions

# %% [markdown]
# **Creating an RDD to explain "RDD actions with Examples"**

# %%
data=[("Z", 1),("A", 20),("B", 30),("C", 40),("B", 30),("B", 60)]

inputRDD = spark.sparkContext.parallelize(data)

listRdd = sc.parallelize([1,2,3,4,5,3,2])

from operator import add

# %% [markdown]
# After creating two RDD’s as given above, we use these two as and when necessary to demonstrate the RDD actions.

# %% [markdown]
# **first()** – Return the first element in the dataset.

# %%
#first
print("first :  "+str(listRdd.first()))

print("first : ", str(inputRDD.first()))
# Out:
# first :  1
# first :  ('Z', 1)

# %% [markdown]
# **take()** – Return the first num elements of the dataset.

# %%
#take()
print("take : "+str(listRdd.take(2)))
# Out:
# take : [1, 2]

# %% [markdown]
# **takeSample()** – Return the subset of the dataset in an Array.

# %%
print("take : "+str(listRdd.takeSample(0,3))) # ([1,2,3,4,5,3,2])
# Out:
# take : [5, 3, 2]

# %% [markdown]
# **takeOrdered()** – Return the first num (smallest) elements from the dataset and this is the opposite of the take() action.

# %%
print("takeOrdered : "+ str(listRdd.takeOrdered(2)))
# Out:
# takeOrdered : [1, 2]

# %% [markdown]
# **collect()** - Return the complete dataset as an Array.

# %%
#Collect
data = listRdd.collect()
data
# Out:
# [1, 2, 3, 4, 5, 3, 2]

# %% [markdown]
# **count()** – Return the count of elements in the dataset.

# %%
print("Count : "+str(listRdd.count()))
# Out:
# Count : 7

# %% [markdown]
# **countByValue()** – Return Map[T,Long] key representing each unique value in dataset and value represents count each value present.

# %%
print("countByValue :  "+str(listRdd.countByValue()))
# Out:
# countByValue :  defaultdict(<class 'int'>, {1: 1, 2: 2, 3: 2, 4: 1, 5: 1})

# %% [markdown]
# **reduce()** – Reduces the elements of the dataset using the specified binary operator.

# %%
redRes=listRdd.reduce(add)
redRes
# Out:
# 20

# %% [markdown]
# **top()** – Return top n elements from the dataset.

# %%
print("top : "+str(listRdd.top(2)))
print("top : ", str(inputRDD.top(2)))
# Out:
# top : [5, 4]
# top :  [('Z', 1), ('C', 40)]

# %% [markdown]
# **fold()** - Aggregate the elements of each partition, and then the results for all the partitions, using a given associative function and a neutral "zero value."

# %%
foldRes=listRdd.fold(0, add)
foldRes
# Out:
# 20

# %% [markdown]
# **foldByKey()** -  is quite similar to fold() both use a zero value of the same type of the data in our RDD and combination function.

# %%
inputRDD.foldByKey(0, add).collect()
# Out:
# [('C', 40), ('Z', 1), ('A', 20), ('B', 120)]

# %% [markdown]
# **reduceByKey()** - Merge the values for each key using an associative reduce function.

# %%
sorted(inputRDD.reduceByKey(add).collect())
# Out:
# [('A', 20), ('B', 120), ('C', 40), ('Z', 1)]

# %% [markdown]
# **combineByKey()** - Generic function to combine the elements for each key using a custom set of aggregation functions.

# %%
def f(inputRDD):
  return inputRDD
def add(A, B):
  return A + str(B)
sorted(inputRDD.combineByKey(str, add, add).collect())
# Out:
# [('A', '20'), ('B', '303060'), ('C', '40'), ('Z', '1')]

# %% [markdown]
# ### PySpark User Defined Functions

# %% [markdown]
# * PySpark UDF is a User Defined Function that is used to create a reusable
# function in Spark.
#
# * Once UDF is created, that can be re-used on multiple DataFrames and SQL (after registering).
#
# * The default type of the udf() is StringType.

# %% [markdown]
# Created dataframe with two columns "Seqno" and "Name"

# %%
columns = ["Seqno","Name"]
data = [("1", "john jones"),
    ("2", "tracey smith"),
    ("3", "amy sanders")]

df = spark.createDataFrame(data,schema=columns)
df.show()
# Out:
# +-----+------------+
# |Seqno|        Name|
# +-----+------------+
# |    1|  john jones|
# |    2|tracey smith|
# |    3| amy sanders|
# +-----+------------+

# %% [markdown]
# Applying UDF

# %%
# creating a udf using lambda
convertUDF = udf(lambda z: z.upper())

df.select(col("Seqno"), convertUDF(col("Name")).alias("Name") ).show(truncate=False)
# Out:
# +-----+------------+
# |Seqno|Name        |
# +-----+------------+
# |1    |JOHN JONES  |
# |2    |TRACEY SMITH|
# |3    |AMY SANDERS |
# +-----+------------+

# %% [markdown]
# #### **Shuffle Operations**

# %% [markdown]
# Shuffling is a mechanism PySpark uses to redistribute the data across different executors and even across machines. PySpark shuffling triggers when we perform certain transformation operations like gropByKey(), reduceByKey(), join() on RDDS
#
# Spark also supports transformations with wide dependencies, such as groupByKey and reduceByKey. In these dependencies, the data required to compute the records in a single partition can reside in many partitions of the parent dataset.
#
# To perform these transformations, all of the tuples with the same key must end up in the same partition, processed by the same task. To satisfy this requirement, Spark performs a shuffle, which transfers data around the cluster and results in a new stage with a new set of partitions.
#
# For example, consider the following code:
#
# **sc.textFile("someFile.txt").map(mapFunc).flatMap(flatMapFunc).filter(filterFunc).count()**
#
# It runs a single action, count, which depends on a sequence of three transformations on a dataset derived from a text file. This code runs in a single stage because none of the outputs of these three transformations depend on data that comes from different partitions than their inputs.

# %% [markdown]
# **Below is an example implementing RDD based model to count the words given in a file**

# %% [markdown]
# To implement RDD based model, we have used the text file (**Spark_Text.txt**) which includes Apache Spark notes/information. This text file contains 5 paragraphs of information on Spark.
#
# We would perform RDD Transformations and Actions on the file to count the words given in the text file.

# %%
rdd = sc.textFile("Spark_Text.txt")

# %%
#To lower the case of each word of a document, we can use the map transformation.

def Func(lines):
      lines = lines.lower()
      lines = lines.split()
      return lines

rdd1 = rdd.map(Func)

# %%
rdd1.take(1)
# Out:
# [['apache',
#   'spark',
#   'lets',
#   'you',
#   'treat',
#   'your',
#   'input',
#   'files',
#   'almost',
#   'like',
#   'any',
#   'other',
#   'variable,',
#   'which',
#   'you',
#   'cannot',
#   'do',
#   'in',
#   'hadoop',
#   'mapreduce.']]

# %%
#To get the flat output, we need to apply a transformation which will flatten the output, The transformation “flatMap" will help here:
rdd2 = rdd.flatMap(Func)
rdd2.take(3)
# Out:
# ['apache', 'spark', 'lets']

# %%
rdd3 = rdd2.filter(lambda x:x!= '')
rdd3.take(7)  # We can check first 7 elements of “rdd3” by applying take action.
# Out:
# ['apache', 'spark', 'lets', 'you', 'treat', 'your', 'input']

# %%
rdd3_mapped = rdd3.map(lambda x: (x,1))
rdd3_grouped = rdd3_mapped.groupByKey()

# %%
rdd3_mapped.reduceByKey(lambda x,y: x+y).map(lambda x:(x[1],x[0])).sortByKey(False).take(200)
# Out:
# [(13, 'the'),
#  (7, 'a'),
#  (6, 'of'),
#  (6, 'you'),
#  (5, 'rdd'),
#  (4, 'that'),
#  (4, 'to'),
#  (4, 'it'),
#  (3, 'are'),
#  (3, 'when'),
#  (3, 'an'),
#  (3, 'spark'),
#  (3, 'rdds'),
#  (3, 'number'),
#  (3, 'be'),
#  (3, 'partitions'),
#  (3, 'has'),
#  (2, 'in'),
#  (2, 'partitions,'),
#  (2, 'execute'),
#  (2, 'is'),
#  (2, 'more'),
#  (2, 'rdd.'),
#  (2, 'new'),
#  (2, 'rdd,'),
#  (2, 'keeps'),
#  (2, 'which'),
#  (2, 'automatically'),
#  (2, 'distributed'),
#  (2, 'across'),
#  (2, 'divided'),
#  (2, 'and'),
#  (2, 'some'),
#  (2, 'all'),
#  (2, 'function'),
#  (2, 'on'),
#  (2, 'creates'),
#  (2, 'does'),
#  (2, 'not'),
#  (1, 'treat'),
#  (1, 'input'),
#  (1, 'files'),
#  (1, 'like'),
#  (1, 'other'),
#  (1, 'variable,'),
#  (1, 'cannot'),
#  (1, 'do'),
#  (1, 'hadoop'),
#  (1, 'network'),
#  (1, 'means'),
#  (1, 'into'),
#  (1, 'task'),
#  (1, 'means,'),
#  (1, 'decides'),
#  (1, 'but'),
#  (1, 'creating'),
#  (1, 'these'),
#  (1, 'nodes'),
#  (1, 'network.'),
#  (1, 'applies'),
#  (1, 'on.(remember'),
#  (1, 'also,'),
#  (1, 'pointer'),
#  (1, 'parent'),
#  (1, 'call'),
#  (1, 'transformation,'),
#  (1, 'instead'),
#  (1, 'lineage.'),
#  (1, 'transformations'),
#  (1, 'applied'),
#  (1, 'where'),
#  (1, 'read'),
#  (1, 'apache'),
#  (1, 'lets'),
#  (1, 'your'),
#  (1, 'almost'),
#  (1, 'any'),
#  (1, 'mapreduce.'),
#  (1, 'by'),
#  (1, 'partitions.'),
#  (1, 'smaller'),
#  (1, 'chunks'),
#  (1, 'called'),
#  (1, 'action,'),
#  (1, 'launched'),
#  (1, 'per'),
#  (1, 'partition.'),
#  (1, 'will'),
#  (1, 'parallelism.'),
#  (1, 'into,'),
#  (1, 'can'),
#  (1, 'also'),
#  (1, 'specify'),
#  (1, 'transformation'),
#  (1, 'modify'),
#  (1, 'apply'),
#  (1, 'resilient/immutable).'),
#  (1, "it's"),
#  (1, 'immediately,'),
#  (1, 'lineage'),
#  (1, 'track'),
#  (1, 'what'),
#  (1, 'including'),
#  (1, 'from'),
#  (1, 'data')]

# %% [markdown]
# **In the below example we can see Spark Transformations in Python using a CSV file.**

# %% [markdown]
# We will use this CSV file (**Google_Books.csv**) to work on Spark Transformations.
#
# This data was acquired from the Google Books store. Google API was used to acquire the data. Nine features were gathered for each book in the data set.

# %%
book_names = sc.textFile("google_books.csv")
rows = book_names.map(lambda line: line.split(",")) #we are creating a new RDD called “rows” by splitting every row in the book_names RDD.

# %%
for row in rows.take(rows.count()):
  print(row[0])
# Out:
# title
# Sammy Keyes and the Art of Deception
# Inward Journey
# The Boston Directory ...
# Bring Your Own Devices (BYOD) Survival Guide
# Enterprise 2.0
# The CIO's Guide to Oracle Products and Solutions
# Implementing the IT Balanced Scorecard
# Implementing the Project Management Balanced Scorecard
# Social Software Engineering
# Classes on Modern Poets and the Art of Poetry
# Population Health Science
# Retelling the Nicaraguan Revolution as a Dionysian Ritual
# Flowers for Algernon
# Handbook of Applied Developmental Science
# Wade Keyes' introductory lecture to the Montgomery Law School
# The Journal of the Iowa Academy of Science
# Dental Science in a New Age
# List of the Scientific Writings of Charles Rollin Keyes
# A Study Guide for Daniel Keyes's Flowers for Algernon
# Domain-based Parallelism and Problem Decomposition Methods in Computational Science and Engineering
# United States Department of Commerce Telephone Directory
# Implementing the IT Balanced Scorecard
# Technology Trendlines
# Biography and Genealogy Master Index
# Technical Paper - Bureau of Mines
# The Corporate Directory of US Public Companies 1995
# "The National Deans List
# Who's who in Technology
# The United States Patents Quarterly
# ACSA Annual Directory
# "World War II: the Encyclopedia of the War Years
# Bulletin - New Mexico Bureau of Mines & Mineral Resources
# Whitaker's Five-year Cumulative Book List
# American Predator
# Whitaker's Cumulative Book List
# "Business Organizations
# Next-Generation Biofuels
# "Casenote Legal Briefs for Business Organizations
# No Oath Sworn
# Southern Writers
# Therapist's Guide to Positive Psychological Interventions
# A Handbook for the Study of Mental Health
# Foundations of Professional Psychology
# Implementing the IT Balanced Scorecard
# Brain Mystery Light and Dark
# The Courage to Write
# Epidemiology Matters
# "Thermodynamic Functions of Gases: Ammonia
# Journal of Heat Transfer
# Data Modeling Essentials
# CliffsNotes on Keyes' Flowers For Algernon
# The Infernal City: An Elder Scrolls Novel
# Sushi for Beginners
# Angels
# Science Fiction and Fantasy Literature
# Independence Day: Crucible
# The Mammoth Encyclopedia of Science Fiction
# The Mystery of Mercy Close
# The New Orleans of Fiction
# Lord of Souls
# "The Dardanelles Campaign
# The Routledge Handbook of Stylistics
# The Liberation Trilogy Box Set
# Legacy Discovered
# "Masterplots II
# Elisha Jones House and Shed
# An Unpredictable Gospel
# Masterplots II.
# Flowers for Algernon
# Stories and Poems for Opening Exercises
# "The Encyclopedia of Superheroes on Film and Television
# Flowers for Algernon
# Fishery Bulletin
# CliffsNotes on Keyes' Flowers For Algernon
# Sammy Keyes and the Kiss Goodbye
# Sammy Keyes and the Skeleton Man
# Sammy Keyes and the Psycho Kitty Queen
# Sammy Keyes and the Art of Deception
# Sammy Keyes and the Search for Snake Eyes
# Caii Spectrum Or Dr. Keyes's Charge Against Dr. M -- [i.e. Dr. Richard Mead]
# Resources in Education
# Chicano School Failure and Success
# The Politics of Hispanic Education
# Desegregation and Education Concerns of the Hispanic Community
# Linguistic Diversity and National Unity
# Synergic Integration of Formal and Informal E-Learning Environments for Adult Lifelong Learners
# "Race and Education
# Wade Keyes' introductory lecture to the Montgomery Law School
# Education and the Cult of Efficiency
# Readings on Equal Education
# The Worcester Directory
# American Predator
# Kill Rommel!
# Murder in Hollywood
# "The Somerville
# "Greenough
# Benham's Embracing a Limited Sketch of Yale College
# The Wisconsin Magazine of History
# Wisconsin magazine of history
# Rutland Directory
# New Evidence on School Desegregation
# Brunswick
# Downstage Dead
# School as Community
# Euphemania
# Complex Justice
# "Five Miles Away
# Learning Disabilities
# California's Charter Schools
# America in Black and White
# PC Mag
# PC Mag
# PC Mag
# PC Mag
# PC Mag
# Computer Decisions
# Fifth International Symposium on Domain Decomposition Methods for Partial Differential Equations
# Personal Computing
# Data sources
# History of the ... Economic Censuses
# A University of Tradition
# Biology Pamphlets
# Biology of the Uterus
# Prophets of Agroforestry
# "Periodontal Disease
# Columbia University Quarterly
# Advances in Experimental Medicine and Biology
# Biology and Pathology of the Oocyte
# A. B. Bookman's Weekly
# Human Biology
# Quarterly Report
# The Anatomy of Hope
# The Journal of the American Medical Association
# Bioethical and Evolutionary Approaches to Medicine and the Law
# Official Gazette of the United States Patent Office
# Directory ... American College of Physicians
# The Azusa Street Mission and Revival
# Directory
# "Periodontal disease
# Standard Directory of Advertising Agencies
# Mental Health Challenges in Elite Sport: Balancing Risk with Reward
# "Sport
# "Casenote Legal Briefs for Sports Law
# "Women
# A Concise history of sport in Canada
# Biography and Genealogy Master Index 2003
# Biography and Genealogy Master Index
# Sams Teach Yourself Perl in 21 Days
# Sammy Keyes and the Psycho Kitty Queen
# "Casenote Legal Briefs for Taxation
# The Mystery of Sex
# Delirium
# American Movie Critics
# The International Encyclopedia of Sexuality: Spain to the United States
# CliffsNotes on Keyes' Flowers For Algernon
# "The American Bar
# "Family Law
# "Casenote Legal Briefs for Property Keyed to Dukeminier
# "Family Law
# "Family Law
# Brain Mystery Light and Dark
# "The Tryals and Condemnation of Robert Charnock
# Adult Development and Aging
# Saved by Cake
# Science and the Riddle of Consciousness
# Sammy Keyes and the Art of Deception
# Sammy Keyes and the Search for Snake Eyes
# "Environmental Law
# Beyond Identity
# Sammy Keyes and the Skeleton Man
# "Bel Marin Keys Development
# Handbook of Midlife Development
# Textbook of Operative Dentistry
# Legacy Discovered
# Parasitic Orobanchaceae
# Strategies and Saints
# The Economist Development Report
# "The Handbook of Life-Span Development
# Journal of the Iowa Archeological Society
# Localizing development
# "Oxford English-Arabic Dictionary
# "Al-Muhit-English-Arabic Oxford Study Dictionary
# "English-Arabic Oxford-Duden Pictorial Dictionary
# Get Rommel
# Omega
# Mastering Arabic 1
# Arabic Musical Scales
# Advanced standard Arabic through authentic texts and audiovisual materials: Audiovisual materials
# اللغة العربية للمراحل المتقدمة من خلال نصوص ومواد سمعية بصرية أصيلة
# Geoffrey Keyes
# صغر عقلك
# الآراء والمعتقدات
# دع القلق وابدأ الحياة
# كيف أصبحوا عظماء
# ١٠١ طريقة بسيطة لتكون ناجحًا مع نفسك
# الثقة بالنفس وتطوير الذات
# فن وأسرار اتخاذ القرار
# دراسات سيكلوجية
# أيقظ قواك الخفية (كيف تتحكم فوراً بمستقبلك الذهني والعاطفي والجسماني والمالي)
# قوة التحكم في الذات
# Advances in Electronics and Electron Physics
# Advances in Chemical Physics
# Advances in Imaging and Electron Physics
# The physics of VLSI systems
# American Men of Science
# Directory of Physics & Astronomy Staff Members
# American men & women of science
# The Complete Guide to Blender Graphics
# "The world of learning
# The Europa world of learning
# A Survey of American Chemistry
# Annual Report for Fiscal Year ...
# Biographical Memoirs
# Commencement
# "Organic Chemistry
# American Men of Science
# Timetable
# The Journal of Engineering Education
# Imperfect Chemistry
# Sammy Keyes and the Psycho Kitty Queen
# Commencement[programme]
# Register - University of California
# Commencement
# Grants and Awards for the Fiscal Year Ended ...
# Academic Press Dictionary of Science and Technology
# The Quality Management Sourcebook
# Software Engineering Handbook
# Mechanical Engineering
# A Survey of American Chemistry
# Wastes Engineering
# Directory
# Transescence
# American Doctoral Dissertations
# The National Faculty Directory
# Who's who in Science and Engineering
# "Who's Who Among Human Services Professionals
# Who's who in the West
# Who's who in America
# نحن كلنا متشابهون، نحن كلنا مختلفون
# Handbook of Social Indicators and Quality of Life Research
# The Woman Who Stole My Life
# The life of Elisha Williams Keyes
# Stevie Wonder's Songs in the Key of Life
# Key Notes of Health and a Century of Life
# Growing Through Life's Challenges
# "Handbook of Adolescent Psychology
# "A Critical Dictionary of English Literature and British and American Authors
# The Post-Truth Era
# "The early life of Robert M. La Follette
# Academic Press Dictionary of Science and Technology
# Data Science on the Google Cloud Platform
# The Oxford Handbook of Research Strategies for Clinical Psychology
# Data Science and Knowledge Engineering for Sensing Decision Support
# Population Health Science
# Business data processing
# "Reverse Acronyms
# Cryptographic Hardware and Embedded Systems – CHES 2008
# The Biblical Basis for Modern Science
# "Hearings
# Carpentry and joinery
# "Retail Crime
# Symposium on Electronics Maintenance
# Symposium on Electronics Maintenance
# Selected Areas in Cryptography -- SAC 2013
# Modern Concepts of Security
# English Mechanic and World of Science
# Research Bulletin
# Mechanics Magazine
# Building Security Standards
# "Fifty Years' Observations of Men and Events
# "Emanuel Law Outlines for Civil Procedure
# Civil Procedure
# "Casenote Legal Briefs for Civil Procedure
# "Casenote Legal Briefs for Civil Procedure Keyed to Hazard
# "Casenote Legal Briefs for Civil Procedure Keyed to Subrin
# "Casenote Legal Briefs for Civil Procedure
# "Proceedings of the Second International Conference on Computing in Civil Engineering
# A Bibliography of Florida: 1881-1899
# "Engineering Mechanics Devoted to Mechanical Civil
# Library of Congress Subject Headings
# Library of Congress Subject Headings
# Rap Music and Street Consciousness
# Sammy Keyes and the Skeleton Man
# That's the Joint!
# Columbian Cyclopedia
# Alden's Manifold Cyclopedia of Knowledge and Language
# Ethnomusicology at UCLA.
# Catalog of Copyright Entries
# Sammy Keyes and the Kiss Goodbye
# Tales From Boilermaker Country: A Collection of the Greatest Stories Ever Told
# War Football
# African Americans in Sports
# Black Champions of the Gridiron
# Football's Most Wanted
# The USA TODAY College Football Encyclopedia 2008-2009
# ESPN college football encyclopedia
# The Howitzer
# Sammy Keyes and the Skeleton Man
# American Book Publishing Record
# "Casenote Legal Briefs for Sports Law
# "Casenote Legal Briefs for Taxation
# School Activities
# "Casenote Legal Briefs for Torts
# School Activities and the Library
# "Casenote Legal Briefs for Contracts
# Contracts
# Higher Education Exchange 78/79
# A Multiple-continuous Offense for High School Basketball
# The Coaching Clinic
# Cumulative List of Organizations Described in Section 170 (c) of the Internal Revenue Code of 1986
# Cumulative List of Organizations Described in Section 170 (c) of the Internal Revenue Code of 1954
# Our Ewing family
# Century of American Savings Banks
# Best books on the stock market
# Cracks in My Foundation
# "Guide to U.S. Foundations
# Corporate Giving Directory
# The Foundation Directory
# Key and allied families
# Text Processing in Python
# Python in a Nutshell
# Programming Python
# Mastering Python for Networking and Security
# SAS Viya
# Python Essential Reference
# Python Programming for Arduino
# Effective Python
# Programming with Python
# "Game Programming with Python
# Python Web Scraping Cookbook
# Topics in Cryptology – CT-RSA 2018
# Python All-in-One For Dummies
# "Understanding the Interactive Digital Media Marketplace: Frameworks
# Enterprise 2.0
# the scientific review and scientific and literary review
# Engineering and Mining Journal
# يوميات آن فرانك
# Paper Trade Journal
# American Machinist
# Academic Press Dictionary of Science and Technology
# Computer Programming And Operating Guide
# Programming Amazon Web Services
# Structured Programming with COBOL Examples
# Planning a library building: the major steps
# Concurrent Programming on Windows
# Modula-2 Programming
# Dictionary of Acronyms and Technical Abbreviations
# MOS databook
# Michigan Education Directory and Buyer's Guide
# "Solar Heating and Cooling Demonstration Act of 1974
# "Solar Heating and Cooling Demonstration Act of 1974
# New Scientist
# Solar Home Heating and Cooling Demonstration Act
# Consumer Handbook of Solar Energy for the United States and Canada
# Disposal of brine by solar evaporation
# New Scientist
# Solar Energy in Developing Countries
# Alternative Sources of Energy
# Architecture Series: Bibliography
# Bulletin
# The Nature of Symbiotic Stars
# Mineral Resources of Southwestern Oregon
# Geological Survey Bulletin
# A Life of Barbara Stanwyck
# From the Dreadnought to Scapa Flow
# Sammy Keyes and the Art of Deception
# Leonard Maltin's movie encyclopedia
# From the Dreadnought to Scapa Flow: Victory and aftermath
# Sammy Keyes and the Skeleton Man
# Princeton Alumni Weekly
# Black Champions of the Gridiron
# Sammy Keyes and the Search for Snake Eyes
# Indian Gaming Regulatory Act
# The Eisenhowers
# Code of Federal Regulations
# List of C.F.R. Sections Affected
# American Lawn Tennis
# Sammy Keyes and the Art of Deception
# Sammy Keyes and the Psycho Kitty Queen
# Sammy Keyes and the Sisters of Mercy
# Enterprise 2.0
# Sammy Keyes and the Wedding Crasher
# Soil Conservation
# The Phone Book
# National Petroleum News
# The Keyes of the Kingdom of Heaven
# Marconi's International Register
# NPN Fact Book
# Who's who Among Students in American Universities and Colleges
# Smart Phone and Next Generation Mobile Computing
# Smartphones
# Casenote Legal Briefs for Criminal Procedure Keyed to Dressler and Thomas
# "The Complete Book of Locks and Locksmithing
# "Casenote Legal Briefs for Contracts
# Asia Electronics Industry
# Sammy Keyes and the Art of Deception
# Sammy Keyes and the Skeleton Man
# Sammy Keyes and the Search for Snake Eyes
# The Phone Book
# Politics in Pacific Asia
# "Music
# Religious Commodifications in Asia
# The Riddle of Barack Obama
# Asian Visions of Authority
# Arguing About Religion
# Readings in philosophy of religion
# United States Political Science Documents
# "Religion
# Directory of departments and programs of religious studies in North America
# Blasphemy
# Whose God Rules?
# "Atheism and Arithmetic
# Atheism And The Case Against Christ
# America Declares Independence
# Gods Arrow Against Atheists
# Gods Arrow Againste Atheists
# The Indian Libertarian
# Brain Mystery Light and Dark
# "101 Proofs that the Bible is True
# Bulletin of the United States Geological Survey
# Get Rommel
# Annual Report of the Commissioner of Patents
# Sammy Keyes and the Wedding Crasher
# The Bloody Man
# Self-instruction in Practical Business Qualifications
# 1000 Helpful Hints & Valuable Suggestions for Book-keepers and Business Men
# The Railway Agent and Station Agent
# Devonshire Scream
# Gaywyck
# Decisions and Orders of the National Labor Relations Board
# Food Shortages: Sugar
# Biennial Report of the Dairy and Food Commissioner of Wisconsin for the Years ...
# Food Shortages
# Annual Report of the Dairy and Food Commissioner of Wisconsin
# Biennial Report of the Dairy and Food Commissioner of Wisconsin
# "Food in the Movies
# Chilton's Food Engineering
# Sammy Keyes and the Hotel Thief
# Child Psychopathology
# Directory of Historic House Museums in the United States
# American Furniture in the Metropolitan Museum of Art
# Catalog of Copyright Entries. Third Series
# American Furniture
# American furniture 1997
# Register of Retirement Benefit Plans Reported Under the Welfare and Pension Plans Disclosure Act
# The Jamestown Furniture Industry
# National Hardwood Magazine
# MacRae's Blue Book
# New Orleans. Ediz. inglese
# Advances in Information Security and Assurance
# The Complete Guide to Physical Security
# Enterprise 2.0
# The Official (ISC)2 Guide to the SSCP CBK
# NET Security and Cryptography
# Maximum Windows 2000 Security
# Information Security and Cryptology - ICISC 2011
# Engineering Information Security
# "The Complete Book of Home
# High-Rise Security and Fire Life Safety
# Analyzing the Hospital Life Safety Survey
# Halo: The Cole Protocol
# Role Development in Professional Nursing Practice
# A Question of Identity
# "The Chapter Leader's Guide to Life Safety
# Cumulated Index Medicus
# "Business Law
# Technical Digest
# Chameleon Christianity
# Sammy Keyes and the Kiss Goodbye
# Stolen Away
# "Billy Wilder
# The Astrology of Film
# "Soulsville
# Three Classic Thrillers 3-Book Bundle
# West's Southern Reporter
# American Movie Critics
# Sammy Keyes and the Kiss Goodbye
# "Fisher
# "Self-government
# Literary Readings of Billy Wilder
# Love Inspired Suspense December 2014 - Box Set 1 of 2
# L.A. Rex
# Cold Case Justice
# Sammy Keyes and the Art of Deception
# Sammy Keyes and the Wedding Crasher
# Catwoman (2011-) #27
# Sammy Keyes and the Night of Skulls
# Sammy Keyes and the Search for Snake Eyes
# Southern California Quarterly
# Mastering Windows XP Home Edition
# Special Edition Using Filemaker 8
# Rehab Brief
# Knowledge-Based Intelligent Information and Engineering Systems
# Alan Simpson's Windows Vista Bible
# How to Do Everything with Windows Vista
# "MICROPROCESSORS
# "Activity Catalog Tool (ACT) User Manual
# Advances in Information Technology Research and Application: 2013 Edition
# Asset Protection through Security Awareness
# الإسلام الديمقراطي المدني
# "Al-Muhit-English-Arabic Oxford Study Dictionary
# "Oxford English-Arabic Dictionary
# Senouhi Cumulative Book Index for Egyptian Region UAR
# رؤيتي
# Iraqi Constitutional Studies
# الحب والجمال عند العرب
# اللؤلؤة
# Mudhakarat talib
# الطائفة، الطائفية، الطوائف المتخيلة
# وحوش من الماضي
# Iraqi Constitutional Studies
# الطائفة، الطائفية، الطوائف المتخيلة
# رسائل فلسفية
# موسوعة تاريخ الأديان
# مصادر تطوير تعليم الرياضيات
# أضواء على الطرق الصوفية في القارة الأفريقية
# Khor Rori (Sumhuram)
# قضية الشعر الجاهلى فى كتاب ابن سلام
# الجمع والتصنيف لمقاصد الشرع الحنيف
# عصر القرود
# Iraqi Constitutional Studies
# رواية : البحث عن الجذور
# سيره امين المؤمنين عمر بن الخطاب شخصيته وعصره
# من جماليات التصوير في القرآن الكريم
# موسوعة تاريخ الأديان
# الطائفة، الطائفية، الطوائف المتخيلة
# الاستبداد من الخلافة للرئاسة
# "Finance and Development
# الله والإنسان في القرآن: علم دلالة الرؤية القرآنية للعالم
# The Minds of Billy Milligan
# أساسيات تصميم المنطق والحاسب
# يوميات آن فرانك
# The Red Badge of Courage (Arabic Edition)
# Stand By Me
# خمسة عقول لأجل المستقبل
# نقطة التحول
# You Can Heal Your Life
# The E-Myth Revisited (Limadha tafshal mu’dham al-sharikat al-saghira?)
# ʻĀʼid ilá Ḥayfā
# قواعد اللغة الإنكليزية
# ‏لغة العربية للشئون التجارية : المرحلة المتقدمة
# اللغة العربية للمراحل المتقدمة من خلال نصوص ومواد سمعية بصرية أصيلة
# "Al-Muhit-English-Arabic Oxford Study Dictionary
# "Oxford English-Arabic Dictionary
# دائرة المعارف
# al-Thaqāfah
# الإسلام الديمقراطي المدني
# رؤيتي
# Senouhi Cumulative Book Index for Egyptian Region UAR
# Happiness Key
# Three Prescriptions for Happiness
# Handbook of Research Methods and Applications in Happiness and Quality of Life
# Hypnofacts 7
# Discovering the Secrets of Happiness
# The Routledge Handbook of Positive Communication
# "How to make your life work
# Presidential Follies
# Person to Person
# Small Press Record of Books in Print
# The Internal Revenue Record and Customs Journal
# "The Tryals of Robert Charnock
# "The Tryals and Condemnation of Robert Charnock
# "Hearing on H.R. 1231
# Naval War College Review
# The life of Elisha Williams Keyes
# International Record of Medicine and General Practice Clinics
# The Mechanical Engineer's Pocket-book
# Carroll's State Directory
# Milton and This Pendant World
# General McClellan's Peninsula Campaign
# Journal
# Journal of the Military Service Institution of the United States
# The Story of One Regiment in the War of the Rebellion
# The War of the Rebellion
# "Fifty Years' Observations of Men and Events
# "Fifty Years' Observation of Men and Events
# Report of Major-General B. McClellan
# Reports of Committees
# All for the Union
# The Keyed Bugle
# Network-Aware Security for Group Communications
# Bluescreen Compositing
# "Advances in Computing and Communications
# Basic Blueprint Reading and Sketching
# Basic TV Technology
# Basic Radio
# InfoWorld
# The Gamification of Work
# NS Basic Programming for Palm OS
# "Commerce
# The Iron Age
# Chilton Automobile Directory
# American Machinist
# Directory of Environmental Life Scientists: Ohio River Valley region
# Thomas Register of American Manufacturers
# The Eclectic Library Catalog
# Current Policies and Practices in European Social Anthropology Education
# Human Development in the Indian Context
# Key Debates in Anthropology
# Social Adaptation to Food Stress
# Karma
# Anthropological Practice
# "Cultural Differences
# Current Policies and Practices in European Social Anthropology Education
# Applications of Anthropology
# Southeast Asian Research Tools: Thailand
# NASA technical note
# Technology Review
# "Adams' New Musical Dictionary of Fifteen Thousand Technical Words
# Technical Research Note
# Refrigeration Engineering
# Sammy Keyes and the Art of Deception
# AB Bookman's Weekly
# Sammy Keyes and the Search for Snake Eyes
# ACSA Annual Directory
# The Play of Daniel Keyes' Flowers for Algernon
# The Southern Frontier 1670-1732
# Spanish Peaks Wilderness Area
# Spanish Peaks Wilderness Area
# Journal of the Iowa Archeological Society
# School Achievement and Failure in Portuguese and Spanish Speaking Countries
# World war in Spain
# "The Southern Frontier
# "A Dictionarie in Spanish and English
# The Booklist
# Rhode Island Historical Society Collections
# Biographical Memoirs
# Journal of the Executive Proceedings of the Senate of the United States of America
# Journal of the Executive Proceedings of the Senate
# Who Owns Whom
# Journal of the Executive Proceedings of the Senate of the United States of America
# All this is Louisiana
# Southern Writers
# The Chess Players
# The Career of David Noble
# Joy Street
# Apple parers
# Holstein-Friesian Herd-book
# The Canadian Record of Performance for Purebred Dairy Cattle
# "Holstein-Friesian Herd-book
# Holstein-Friesian Herd Book
# InfoWorld
# The Azusa Street Mission and Revival
# InfoWorld
# Sammy Keyes and the Search for Snake Eyes
# Apple TV Portable Genius
# AFPTRC-TN.
# AFPTRC-TN.
# Advances in Cryptology – EUROCRYPT 2001
# Manuals Combined: U.S. Army Special Forces And Navy Operational Obstetrics & Gynecology With Physical Exam Techniques
# AFHRL-TR.
# "Huffed Masculinity. The Female Threat in Cain's ""Double Indemnity"""
# Teaching Students with Mental Retardation
# Bibliographic Guide to Dance
# Human Motivation and Interpersonal Relationships
# How Mentally Handicapped Children Learn Under Classroom Conditions: Brief screening instruments for evaluating the academic skills and personal adjustment of educable mentally handicapped children
# The life of Elisha Williams Keyes
# Capitol Threat
# Outrageous fortune
# Film Noir
# History of an idea
# Assignment to catastrophe
# Assignment to catastrophe
# Destiny
# Henry Wilson and the Coming of the Civil War
# The Hotline
# Bulletin
# The University Geological Survey of Kansas
# State Geological Survey of Kansas
# Reports on the University Geological Survey of Kansas
# Special Report on Coal
# State Geological Survey of Kansas. [Reports]
# State Geological Survey of Kansas
# Proceedings of the Board of Regents
# Language Planning Processes
# The life of Elisha Williams Keyes
# Sexual Symmetry
# Beginning Blender
# Molecular Symmetry and Spectroscopy
# Identification and System Parameter Estimation
# Proceedings of the ... Midwest Symposium on Circuits and Systems
# The Development of Optically Active Three-fold Symmetric Ligands and Their Application to Stereoselective Organic Transformations
# Solid State Physics
# Journal of Electronics
# Acta Numerica 1994:
# Refined techniques for blind equalization of phase shift keyed (PSK) and quadrature amplitude modulated (QAM) digital communications signals
# "Grief Counseling and Grief Therapy
# Advanced Practice Nursing in the Care of Older Adults
# Small Treasons
# Sammy Keyes and the Power of Justice Jack
# Sammy Keyes and the Psycho Kitty Queen
# Sammy Keyes and the Search for Snake Eyes
# Angels
# Arranging Grief
# Principles and Practice of Grief Counseling
# Charles Henry Keyes
# "Transforming Engagement
# "The Army of the Potomac: Birth of command
# The Army of the Potomac
# Sammy Keyes and the Hollywood Mummy
# Sammy Keyes and the Kiss Goodbye
# Sammy Keyes and the Art of Deception
# Beauty and Sadness
# Sushi for Beginners
# Look Back In Sadness: One Man's Experience with Psychiatry
# The Hope and the Sadness
# Stabilizing the Prices of Certain Agricultural Products
# Translocal Geographies
# Department of Agriculture and Related Agencies Appropriations for Fiscal Year 1970
# Department of Agriculture and Related Agencies Appropriations for Fiscal Year 1970: Program payments made to producers during calendar year 1968; subsidy payments for agricultural exports
# Pacific Rural Press
# "Agricultural Appropriation Bill for 1933
# The Chemist
# Poultry Tribune
# "Report of the Auditor of the State of South Dakota
# "Proceedings of the 8th Pacific Science Congress of the Pacific Science Association Held at the University of the Philippines
# Poultry Success
# Cumulated Index Medicus
# American Poultry Journal
# Poultry Processing and Marketing
# American Poultry Advocate
# Governor's Budget
# Budget Submitted to the California Legislature
# Extension Echoes
# Albany City Directory
# Canadian Poultry Review
# Institute Of Biblical Studies The Book Of Genesis
# International Monetary Fund Annual Report 2007
# Mitteilungen der Münchner Entomologischen Gesellschaft
# الانا الواقعية والذاتية
# نحو تقويم جديد للكتابة العربية
# The Ways of Men (Arabic Edition)
# مقامات الحريري - [اصفر]
# Tales and Fantasies (Arabic Edition)
# Genetics of Psychological Well-Being
# Encyclopedia of Genetics
# Compendium of Problems in Genetics
# Studies in the Genetics of Drosophila
# Bioethical and Evolutionary Approaches to Medicine and the Law
# Sammy Keyes and the Psycho Kitty Queen
# Cardiovascular Genetics and Genomics in Clinical Practice
# American Men and Women of Science
# "Reproductive Genetics
# Molecular Genetics of Sex Determination
# "Bibliography of North American Geology
# "Contributions to Economic Geology (short Papers and Preliminary Reports
# Bulletin
# Invisible Master
# Enochian Magic for Beginners
# The Mexican American and the Law
# Justice for Salcido
# Annual
# Yale journal of law & the humanities
# Merit and the Millennium
# Man of the Mist
# A Historical Guide to Henry David Thoreau
# Soul to soul
# The Lutheran
# Let's Go Soul Winning
# Sammy Keyes and the Night of Skulls
# The Science of the Soul in Colonial New England
# The Keyes of the Kingdom of Heaven
# Sammy Keyes and the Kiss Goodbye
# Kahlil Gibran
# How to Teach Meditation to Children
# Human Rights in Thailand
# Thailand's International Meditation Centers
# Collected poems
# Astral Travel
# Making Fields of Merit
# Meditation For Dummies
# "A meditation upon the Lord's prayer
# Letters on Occult Meditation
# Bottom Line's Health News
# Yoga Journal
# Yoga Journal
# Yoga Journal
# Yoga Journal
# Yoga and Science in Pain Care
# Yoga Journal
# Canadiana
# Yoga Journal
# Anatomy of Hatha Yoga
# Yoga Journal
# Agriculture in Northern Ireland
# Scottish Agriculture
# Sammy Keyes and the Search for Snake Eyes
# Poultry Digest
# Sammy Keyes and the Art of Deception
# Sammy Keyes and the Psycho Kitty Queen
# National Poultry Digest
# Building a Dune Buggy - The Essential Manual
# The Color Correction Handbook
# The Art and Science of Digital Compositing
# Records and Briefs of the United States Supreme Court
# "Helium Production at the Bureau of Mines Keyes
# Decisions and Orders of the National Labor Relations Board
# Road Test
# Motor World Wholesale
# "Motor World for Jobbers
# Standard Directory of Advertising Agencies
# Sammy Keyes and the Psycho Kitty Queen
# Sammy Keyes and the Search for Snake Eyes
# Transit Journal ...
# Automotive News
# Reports of Cases Determined in the Courts of Appeal of the State of California
# Sammy Keyes and the Search for Snake Eyes
# Journal
# Catalog of Copyright Entries. Third Series
# United States Investor
# The National Monthly Stock Summary
# The ... Book of Lists
# Index of Patents Issued from the United States Patent Office
# Science Abstracts
# The Boston Medical and Surgical Journal
# Down East
# Documents of the Assembly of the State of New York
# "Annual Report of the Public Service Commission
# Annual Report
# Documents of the Senate of the State of New York
# 24 Volumes Combined: NEETS - U.S. Navy Electricity and Electronics Training Series
# Specifications and Drawings of Patents Relating to Electricity Issued by the U. S.
# Specifications and Drawings of Patents Relating to Electricity
# Sammy Keyes and the Skeleton Man
# Flowers for Algernon: A Novel by Daniel Keyes (Trivia-On-Books)
# "Art Book News Annual
# Report to Congress
# The Reporter’s Notebook
# The Rotarian
# Far Eastern Economic Review
# Publications of the Navy Records Society
# Directory of Foreign Manufacturers in the United States
# The Hollywood Reporter
# Directory of American Firms Operating in Foreign Countries
# Let's Draw Manga
# Manga
# "Comics
# Manga for the Beginner Shoujo
# The Mineral Resources of New Mexico
# Bulletin
# Bulletin - New Mexico Bureau of Mines & Mineral Resources
# "Watching Anime
# Manga from the Floating World
# Japanese Religions
# "Global Children
# U.S. News & World Report
# Ideas que pegan
# Cyber Ireland
# Creating High-quality Classroom Assignments
# Made to Stick
# "Children's Books in Print
# Television Guide
# Business Periodicals Index
# På egen hand
# The Shining Wall
# Programming Android
# Raspberry Pi Android Projects
# How to Build an Android
# Unlocking Android
# Stranger in a Strange Land
# Red-haired android
# Enterprise 2.0
# Almost Human
# Flowers for Algernon
# iPhone: The Missing Manual
# Beginning iPhone Development
# Beginning iPhone Development with Swift
# Beginning iPhone Development with Swift 3
# Beginning iPhone Development with Swift 4
# Beginning iPhone 4 Development
# iPhone Advanced Projects
# IPhone Fully Loaded
# The IPhone Book
# The Collector
# Android Mobile Computing Using Samsung Tablets and Smartphones Running Android 2.3
# Android Mobile Computing Using Samsung Tablets and Smartphones Running Android 2.3 - Kindle version
# My Samsung Galaxy S5
# My Samsung Galaxy S 4
# My Samsung Galaxy Tab 4
# How to Do Everything Samsung Galaxy Tab
# The PC and Gadget Help Desk
# Android Tips and Tricks
# Teach Yourself VISUALLY Android Phones and Tablets
# "The Healthy PC: Preventive Care
# Bullying in North American Schools
# Reports of the Treasurer and the County Commissioners
# Wilson Library Bulletin
# The Boston Directory
# Lg LB Helping Mom 4pk
# Methods in Immunotoxicology
# Holstein Friesian Register
# Journal of the Senate of Maine
# "Moody's Manual of Investments
# Nuclear Science Abstracts
# Criminology Goes to the Movies
# Shades of Gray
# Tyler Perry
# Costume Design in the Movies
# Sammy Keyes and the Skeleton Man
# The Hollywood Reporter
# CliffsNotes on Keyes' Flowers For Algernon
# Sammy Keyes and the Psycho Kitty Queen
# The Play of Daniel Keyes' Flowers for Algernon
# Godzilla: King of the Monsters - the Official Movie Novelisation
# "Billy Wilder
# A Divided World
# Tyler Perry
# Dark cinema
# Magill's Cinema Annual
# Success in the Cinema MoneyMaking Movies
# Hollywood's dark cinema
# Cinema as Weather
# Science-fiction & Fantasy Cinema
# Cinema of Obsession
# The Digital Hand
# X Internet
# Internet Management
# How to be a Successful Internet Consultant
# Datacasting
# Security Technologies for the World Wide Web
# SCLC
# Web Services
# Going Global: An Information Sourcebook for Small and Medium-sized Businesses
# Enterprise 2.0
# Business Week
# Quantum Roots
# Foundations of Quantum Mechanics in the Light of New Technology
# Foundations of Quantum Mechanics in the Light of New Technology
# Quantum Roots II
# Advances in Cryptology
# Contracts
# "Casenote Legal Briefs for Contracts
# Chaos in Classical and Quantum Mechanics
# Quantum Mechanics with Applications to Nanotechnology and Information Science
# Quantum Electronics
# Commencement
# A Survey of American Chemistry
# "Chemistry
# Grants and Awards for the Fiscal Year Ended ...
# Commencement[programme]
# Molecular Modeling and Theory in Chemical Engineering
# Chemical Engineering
# Concepts of Chemical Engineering 4 Chemists
# Sources of Engineering Information
# Chemical Engineering Progress
# Annual Report of the Bureau of Animal Industry for the Year ...
# Queer Ecologies
# "Nimble
# New Scientist
# National Petroleum News
# Paper Trade Journal
# "Water Use in the Yuba and Bear River Basins
# The Saturday Evening Post
# Ethnomusicology at UCLA
# The Hollywood Reporter
# The Keyes and Gleason families
# الصين شركة عملاقة
# Writers for young adults
# Children's Authors and Illustrators
# Children's Authors and Illustrators
# Minutes of the East Ohio Conference of the Methodist Episcopal Church
# Light Absorption of Organic Colorants
# "Fashion
# Modern Heterocyclic Chemistry
# Biography and Genealogy Master Index
# Cloth in West African History
# تاريخ المكتبات
# The History of the Renaissance World: From the Rediscovery of Aristotle to the Conquest of Constantinople
# القسم الجامعي المنتج للبحوث
# Essays in Indian History
# "Abḥāth al-Nadwah al-ʻĀlamīyah al-Ūlá li-Tārīkh al-ʻUlūm ʻinda al-ʻArab
# Paperbound Books in Print
# Books in Print Supplement
# Essays in Indian History
# دائرة المعارف
# "A History of Women's Hairstyles
# Computerworld
# Religion and Orientalism in Asian Studies
# Doowop
# Register - University of California
# An Unpredictable Gospel
# Waltzing Into the Cold War
# History of an idea
# History of Dane County;
# Beyond Our Means
# CJKV Information Processing
# Sammy Keyes and the Skeleton Man
# Sammy Keyes and the Psycho Kitty Queen
# Adobe Premiere Pro CS3
# Adobe Premiere Pro CS4 Classroom in a Book
# Adobe Premiere Pro 2.0
# Adobe After Effects CC Classroom in a Book (2014 release)
# PDF Reference
# Adobe Kroger
# Adobe ColdFusion Anthology
# Sammy Keyes and the Kiss Goodbye
# Sammy Keyes and the Art of Deception
# Annual Institute on Securities Regulation
# Sammy Keyes and the Dead Giveaway
# Sammy Keyes and the Search for Snake Eyes
# Sammy Keyes and the Psycho Kitty Queen
# The Keyes of the Kingdom of Heaven
# H.A.L.O
# Antiquarian Bookman
# Campaign 2000
# Bulletin
# A Historical Guide to Henry David Thoreau
# Mineral Resources of Alaska
# A Southern Collection
# The Guide to Catholic Literature
# A Study Guide for Daniel Keyes's Flowers for Algernon
# Agenda
# What Do We Tell the Children? Critical Essays on Children’s Literature
# "Foreign languages
# """Swinging London"" by M. Keyes - a Stylistic Analysis of a Sample of Literary Prose"
# "Bibliography of North American Geology
# Bibliography of North American Geology
# Race and Ethnicity in America: From Pre-contact to the Present [4 volumes]
# "Contributions to Economic Geology (short Papers and Preliminary Reports
# Bulletin
# Latin America's Economic Challenge
# Irish America
# The Pan-American Geologist
# Arid Land Geom: Geom Crit Conc
# The Pan-American Geologist

# %%
for row in rows.take(10):
  print(row[0])
# Out:
# title
# Sammy Keyes and the Art of Deception
# Inward Journey
# The Boston Directory ...
# Bring Your Own Devices (BYOD) Survival Guide
# Enterprise 2.0
# The CIO's Guide to Oracle Products and Solutions
# Implementing the IT Balanced Scorecard
# Implementing the Project Management Balanced Scorecard
# Social Software Engineering

# %%
# filter() - Creating a new RDD by returning only the elements that satisfy the search filter.
rows.filter(lambda line: "Inward Journey" in line).collect()
# Out:
# [['Inward Journey',
#   '',
#   'en',
#   "['Medical']",
#   '',
#   'NOT_MATURE',
#   'Open Court Publishing Company',
#   '1983-01',
#   '133']]

# %%
# groupByKey() The following groups all titles to their publisher. Operates on value pairs
rows = book_names.map(lambda line: line.split(","))
titleToPublisher = rows.map(lambda n: (str(n[0]),str(n[6]) )).groupByKey()
titleToPublisher.map(lambda x : {x[0]: list(x[1])}).take(5)
# Out:
# [{'title': ['publisher']},
#  {'The Boston Directory ...': ['']},
#  {"The CIO's Guide to Oracle Products and Solutions": ['CRC Press']},
#  {'Implementing the IT Balanced Scorecard': ['CRC Press',
#    'CRC Press',
#    'CRC Press']},
#  {'Social Software Engineering': ['CRC Press']}]
